# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
from src.parameters import ANIMALS
from loren_frank_data_processing import make_epochs_dataframe, make_tetrode_dataframe

# %%
import pandas as pd
epoch_info = make_epochs_dataframe(ANIMALS)
with pd.option_context('display.max_rows', None, 'display.max_columns', 3):
    display(epoch_info.dropna())
# Out:
#                  environment exposure type
# animal day epoch
# Cor    1   2          TrackA        1  run
#            4          TrackA        2  run
#        2   2          TrackA        3  run
#            4          TrackA        4  run
#        3   2          TrackA        5  run
#            4          TrackA        6  run
#        4   2          TrackA        7  run
#            4          TrackB        1  run
#            6          TrackB        2  run
#        5   2          TrackA        8  run
#            4          TrackB        3  run
#            6          TrackB        4  run
#        6   2          TrackA        9  run
#            4          TrackB        5  run
#            6          TrackB        6  run
#        7   2          TrackA       10  run
#            4          TrackB        7  run
#            6          TrackB        8  run
#        8   2          TrackA       11  run
#            4          TrackB        9  run
#            6          TrackB       10  run
#        9   2          TrackA       12  run
#            4          TrackB       11  run
#            6          TrackB       12  run
# bon    3   2          TrackB        1  run
#            4          TrackB        2  run
#            6          TrackA       13  run
#        4   2          TrackB        3  run
#            4          TrackB        4  run
#            6          TrackA       14  run
#        5   2          TrackB        5  run
#            4          TrackB        6  run
#            6          TrackA       15  run
#        6   2          TrackB        7  run
#            4          TrackB        8  run
#            6          TrackA       16  run
#        7   2          TrackB        9  run
#            4          TrackB       10  run
#            6          TrackA       17  run
#        8   2          TrackB       11  run
#            4          TrackB       12  run
#            6          TrackA       18  run
#        9   2          TrackB       13  run
#            4          TrackB       14  run
#            6          TrackA       19  run
#        10  2          TrackB       15  run
#            4          TrackB       16  run
#            6          TrackA       20  run
# fra    2   2          TrackB        1  run
#            4          TrackB        2  run
#            6          TrackA       13  run
#        3   2          TrackB        3  run
#            4          TrackB        4  run
#            6          TrackA       14  run
#        4   2          TrackB        5  run
#            4          TrackB        6  run
#            6          TrackA       15  run
#        5   2          TrackB        7  run
#            4          TrackB        8  run
#            6          TrackA       16  run
#        6   2          TrackB        9  run
#            4          TrackB       10  run
#            6          TrackA       17  run
#        7   2          TrackB       11  run
#            4          TrackB       12  run
#            6          TrackA       18  run
#        8   2          TrackB       13  run
#            4          TrackB       14  run
#            6          TrackA       19  run
#        9   2          TrackB       15  run
#            4          TrackB       16  run
#            6          TrackA       20  run
#        10  2          TrackB       17  run
#            4          TrackB       18  run
#            6          TrackA       21  run
#        11  2          TrackB       19  run
#            4          TrackB       20  run
#            6          TrackA       22  run
#        12  2          TrackB       21  run
#            4          TrackB       22  run
#            6          TrackA       23  run

# %%
tetrode_info = make_tetrode_dataframe(ANIMALS)
tetrode_info.groupby(['animal', 'day', 'epoch']).area.value_counts().groupby(['animal', 'area']).median()
# Out:
# /projectnb/braincom/edeno/conda_envs/Categorize_Replay_2017/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: 'animal' is both a column name and an index level.
# Defaulting to column but this will raise an ambiguity error in a future version
#
# /projectnb/braincom/edeno/conda_envs/Categorize_Replay_2017/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: 'day' is both a column name and an index level.
# Defaulting to column but this will raise an ambiguity error in a future version
#
# /projectnb/braincom/edeno/conda_envs/Categorize_Replay_2017/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: 'epoch' is both a column name and an index level.
# Defaulting to column but this will raise an ambiguity error in a future version
# animal  area
# Cor     CA1           8
#         CA3           3
#         MEC           6
#         Reference     1
# HPa     CA1           7
#         PFC           6
#         iCA1          7
# HPb     CA1           7
#         PFC           7
#         iCA1          6
# HPc     CA1           7
#         Ctx           6
#         PFC           9
# bon     ???           1
#         CA1          11
#         CA3          13
#         Reference     1
# fra     ???           2
#         CA1           5
#         CA2           3
#         CA3           7
#         DG            1
#         Reference     1
# Name: area, dtype: int64
