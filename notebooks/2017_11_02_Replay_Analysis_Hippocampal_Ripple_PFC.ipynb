# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# Previous notebook (10-31-2017) use CA1, iCA1 and CA3 when available to detect ripples and decode replay events, but our decoding percentage wasn't very good.
#
# This analysis is now just considering each brain area separately, which is more in line (I think) with how Loren's lab does it.

# %%
import pandas as pd
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style='ticks', context='poster', font_scale=0.9,
            rc={'xtick.major.size': 3,
                'ytick.major.size': 3,
                'xtick.major.width': 1,
                'ytick.major.width': 1,
                'xtick.major.pad': 3.5,
                'ytick.major.pad': 3.5,
                'axes.linewidth': 1,
                'lines.linewidth': 2,
               })

from src.parameters import PROCESSED_DATA_DIR, ANIMALS, COLORS
from loren_frank_data_processing import make_epochs_dataframe, read_analysis_files

# %%
epoch_info = make_epochs_dataframe(ANIMALS)
epoch_info = epoch_info.loc[
    (epoch_info.type == 'run') &
    (epoch_info.environment != 'lin')]
epoch_keys = epoch_info.index

# %%
def preprocess(ds):
    return ds.drop(['start_time', 'end_time', 'ripple_duration'])

replay_info = (read_analysis_files(
    PROCESSED_DATA_DIR, epoch_keys, group='hippocampal_ripple/PFC/replay_info',
    preprocess=preprocess)
    .reset_index('recording_session')
     .to_dataframe()
     .dropna()
     .set_index(['animal', 'day', 'epoch', 'ripple_number']))

# %%
replay_info.head(5)
# Out:
#                                  predicted_state  predicted_state_probability  \
# animal day epoch ripple_number
# HPa    4   2     1.0             Inbound-Reverse                     0.289385
#            4     1.0             Inbound-Reverse                     0.288857
#        5   2     1.0             Inbound-Forward                     0.290234
#            4     1.0            Outbound-Reverse                     0.810294
#        6   2     1.0            Outbound-Forward                     0.369180
#
#                                replay_task replay_order session_time  \
# animal day epoch ripple_number
# HPa    4   2     1.0               Inbound      Reverse        early
#            4     1.0               Inbound      Reverse        early
#        5   2     1.0               Inbound      Forward        early
#            4     1.0              Outbound      Reverse        early
#        6   2     1.0              Outbound      Forward        early
#
#                                 number_of_unique_spiking  number_of_spikes  \
# animal day epoch ripple_number
# HPa    4   2     1.0                                 3.0               9.0
#            4     1.0                                 1.0               2.0
#        5   2     1.0                                 3.0              10.0
#            4     1.0                                 4.0              23.0
#        6   2     1.0                                 2.0              14.0
#
#                                trajectory_direction trajectory_turn  \
# animal day epoch ripple_number
# HPa    4   2     1.0                       Outbound            Left
#            4     1.0                        Inbound           Right
#        5   2     1.0                       Outbound            Left
#            4     1.0                        Inbound           Right
#        6   2     1.0                       Outbound            Left
#
#                                 trial_number  linear_distance  x_position  \
# animal day epoch ripple_number
# HPa    4   2     1.0                     3.0        78.044341   97.230572
#            4     1.0                     1.0         0.000000   98.150000
#        5   2     1.0                     2.0        66.330113   97.500000
#            4     1.0                     1.0         0.000000   98.800000
#        6   2     1.0                     8.0       186.904264   63.700000
#
#                                 y_position  head_direction     speed  \
# animal day epoch ripple_number
# HPa    4   2     1.0             19.769428       -2.279660  3.916196
#            4     1.0            104.650000        0.643501  1.069673
#        5   2     1.0             33.150000       -2.634494  1.397077
#            4     1.0            104.650000        0.703446  1.602914
#        6   2     1.0             99.450000        0.524796  0.039076
#
#                                 linear_position replay_motion
# animal day epoch ripple_number
# HPa    4   2     1.0                  13.178888          Away
#            4     1.0                   0.000000       Towards
#        5   2     1.0                 -66.330113          Away
#            4     1.0                   0.000000       Towards
#        6   2     1.0                -186.904264          Away

# %%
replay_info['session_time'] = pd.Categorical(
    replay_info.session_time, ordered=True,
    categories=['early', 'middle', 'late'])

replay_info['replay_task'] = replay_info.replay_task.where(
    replay_info.predicted_state_probability >= 0.8, 'Unclassified')
replay_info['replay_order'] = replay_info.replay_order.where(
    replay_info.predicted_state_probability >= 0.8, 'Unclassified')
replay_info['replay_motion'] = replay_info.replay_motion.where(
    replay_info.predicted_state_probability >= 0.8, 'Unclassified')
replay_info['predicted_state'] = replay_info.predicted_state.where(
    replay_info.predicted_state_probability >= 0.8, 'Unclassified')

# %% [markdown]
# ## Over animals

# %%
covariate = 'replay_order'

replay_percentage = (replay_info
 .groupby(['animal', 'day', 'epoch'])[covariate].value_counts(normalize=True)
 .rename('% of ripples')
 .reset_index())

sns.factorplot(data=replay_percentage, x='animal', y='% of ripples', hue=covariate,
               palette=COLORS, size=5, kind='bar');
sns.factorplot(data=replay_percentage, x='animal', y='% of ripples', hue=covariate,
               kind='swarm', palette=COLORS, size=5);

# %%
covariate = 'replay_task'

replay_percentage = (replay_info
 .groupby(['animal', 'day', 'epoch'])[covariate].value_counts(normalize=True)
 .rename('% of ripples')
 .reset_index())

sns.factorplot(data=replay_percentage, x='animal', y='% of ripples', hue=covariate,
               palette=COLORS, size=5, kind='bar');
sns.factorplot(data=replay_percentage, x='animal', y='% of ripples', hue=covariate,
               kind='swarm', palette=COLORS, size=5);

# %%
covariate = 'replay_motion'

replay_percentage = (replay_info
 .groupby(['animal', 'day', 'epoch'])[covariate].value_counts(normalize=True)
 .rename('% of ripples')
 .reset_index())

sns.factorplot(data=replay_percentage, x='animal', y='% of ripples', hue=covariate,
               palette=COLORS, size=5, kind='bar');
sns.factorplot(data=replay_percentage, x='animal', y='% of ripples', hue=covariate,
               kind='swarm', palette=COLORS, size=5);

# %%
covariate = 'predicted_state'

replay_percentage = (replay_info
 .groupby(['animal', 'day', 'epoch'])[covariate].value_counts(normalize=True)
 .rename('% of ripples')
 .reset_index())

sns.factorplot(data=replay_percentage, x='animal', y='% of ripples', hue=covariate,
               palette=COLORS, size=5, kind='bar');
sns.factorplot(data=replay_percentage, x='animal', y='% of ripples', hue=covariate,
               kind='swarm', palette=COLORS, size=5);

# %% [markdown]
# ## Over Epochs

# %%
covariate = 'replay_order'
replay_percentage = (replay_info
 .groupby(['animal', 'day', 'epoch'])[covariate].value_counts(normalize=True)
 .rename('% of ripples')
 .reset_index()
 .assign(epochs=lambda df: df.day + df.epoch * 0.1))


g = sns.FacetGrid(data=replay_percentage, col='animal', col_wrap=3,
                  hue=covariate, palette=COLORS, size=5)

g = g.map(plt.plot, 'epochs', '% of ripples')
g.add_legend();

# %%
covariate = 'replay_task'

replay_percentage = (replay_info
 .groupby(['animal', 'day', 'epoch'])[covariate].value_counts(normalize=True)
 .rename('% of ripples')
  .reset_index()
 .assign(epochs=lambda df: df.day + df.epoch * 0.1))


g = sns.FacetGrid(data=replay_percentage, col='animal', col_wrap=3,
                  hue=covariate, palette=COLORS, size=5)
g = g.map(plt.plot, 'epochs', '% of ripples')
g.add_legend();

# %%
covariate = 'replay_motion'
replay_percentage = (replay_info
 .groupby(['animal', 'day', 'epoch'])[covariate].value_counts(normalize=True)
 .rename('% of ripples')
  .reset_index()
 .assign(epochs=lambda df: df.day + df.epoch * 0.1))


g = sns.FacetGrid(data=replay_percentage, col='animal', col_wrap=3,
                  hue=covariate, palette=COLORS, size=5)
g = g.map(plt.plot, 'epochs', '% of ripples')
g.add_legend();

# %%
covariate = 'predicted_state'
replay_percentage = (replay_info
 .groupby(['animal', 'day', 'epoch'])[covariate].value_counts(normalize=True)
 .rename('% of ripples')
  .reset_index()
 .assign(epochs=lambda df: df.day + df.epoch * 0.1))


g = sns.FacetGrid(data=replay_percentage, col='animal', col_wrap=3,
                  hue=covariate, palette=COLORS, size=5)
g = g.map(plt.plot, 'epochs', '% of ripples')
g.add_legend();

# %%
covariate = 'replay_order'
percentage_of_ripples = (replay_info.reset_index()
 .groupby(['animal', 'day'])[covariate].value_counts(normalize=True)
 .rename('percentage of ripples').reset_index())

sns.factorplot(data=percentage_of_ripples, x='day', y='percentage of ripples',
               hue=covariate, col='animal', col_wrap=3, palette=COLORS);

# %%
covariate = 'replay_task'
percentage_of_ripples = (replay_info.reset_index()
 .groupby(['animal', 'day'])[covariate].value_counts(normalize=True)
 .rename('percentage of ripples').reset_index())

sns.factorplot(data=percentage_of_ripples, x='day', y='percentage of ripples',
               hue=covariate, col='animal', col_wrap=3, palette=COLORS);

# %%
covariate = 'replay_motion'
percentage_of_ripples = (replay_info.reset_index()
 .groupby(['animal', 'day'])[covariate].value_counts(normalize=True)
 .rename('percentage of ripples').reset_index())

sns.factorplot(data=percentage_of_ripples, x='day', y='percentage of ripples',
               hue=covariate, col='animal', col_wrap=3, palette=COLORS);

# %%
covariate = 'predicted_state'
percentage_of_ripples = (replay_info.reset_index()
 .groupby(['animal', 'day'])[covariate].value_counts(normalize=True)
 .rename('percentage of ripples').reset_index())

sns.factorplot(data=percentage_of_ripples, x='day', y='percentage of ripples',
               hue=covariate, col='animal', col_wrap=3, palette=COLORS);

# %% [markdown]
# ## Within session

# %%
covariate = 'replay_motion'
percentage_of_ripples = (replay_info
 .groupby(['animal', 'day', 'epoch', 'session_time'])[covariate].value_counts(normalize=True)
 .rename('percentage of ripples').reset_index())

sns.factorplot(data=percentage_of_ripples, x='session_time', y='percentage of ripples', hue=covariate, palette=COLORS);
sns.factorplot(data=percentage_of_ripples, x='session_time', y='percentage of ripples', hue=covariate,
               col='animal', palette=COLORS, col_wrap=3);
sns.factorplot(data=percentage_of_ripples, x='session_time', y='percentage of ripples', hue=covariate,
               kind='swarm', palette=COLORS);
sns.factorplot(data=percentage_of_ripples, x='session_time', y='percentage of ripples', hue=covariate,
               col='animal', col_wrap=3, kind='swarm', palette=COLORS);
# Out:
# -------------------------------------------------
# KeyError        Traceback (most recent call last)
# /projectnb/braincom/edeno/conda_envs/Categorize_Replay_2017/lib/python3.6/site-packages/matplotlib/colors.py in to_rgba(c, alpha)
#     140     try:
# --> 141         rgba = _colors_full_map.cache[c, alpha]
#     142     except (KeyError, TypeError):  # Not in cache, or unhashable.
#
# KeyError: (0.33999999999999997, None)
#
# During handling of the above exception, another exception occurred:
#
# ValueError      Traceback (most recent call last)
# <ipython-input-19-f708f7a143f7> in <module>()
#       6 sns.factorplot(data=percentage_of_ripples, x='session_time', y='percentage of ripples', hue=covariate, palette=COLORS);
#       7 sns.factorplot(data=percentage_of_ripples, x='session_time', y='percentage of ripples', hue=covariate,
# ----> 8                col='animal', palette=COLORS, col_wrap=3);
#       9 sns.factorplot(data=percentage_of_ripples, x='session_time', y='percentage of ripples', hue=covariate,
#      10                kind='swarm', palette=COLORS);
#
# /projectnb/braincom/edeno/conda_envs/Categorize_Replay_2017/lib/python3.6/site-packages/seaborn/categorical.py in factorplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, order, hue_order, row_order, col_order, kind, size, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3509
#    3510     # Draw the plot onto the facets
# -> 3511     g.map_dataframe(plot_func, x, y, hue, **plot_kws)
#    3512
#    3513     # Special case axis labels for a count type plot
#
# /projectnb/braincom/edeno/conda_envs/Categorize_Replay_2017/lib/python3.6/site-packages/seaborn/axisgrid.py in map_dataframe(self, func, *args, **kwargs)
#     795
#     796             # Draw the plot
# --> 797             self._facet_plot(func, ax, args, kwargs)
#     798
#     799         # Finalize the annotations and layout
#
# /projectnb/braincom/edeno/conda_envs/Categorize_Replay_2017/lib/python3.6/site-packages/seaborn/axisgrid.py in _facet_plot(self, func, ax, plot_args, plot_kwargs)
#     813
#     814         # Draw the plot
# --> 815         func(*plot_args, **plot_kwargs)
#     816
#     817         # Sort out the supporting information
#
# /projectnb/braincom/edeno/conda_envs/Categorize_Replay_2017/lib/python3.6/site-packages/seaborn/categorical.py in pointplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, markers, linestyles, dodge, join, scale, orient, color, palette, errwidth, capsize, ax, **kwargs)
#    3127         ax = plt.gca()
#    3128
# -> 3129     plotter.plot(ax)
#    3130     return ax
#    3131
#
# /projectnb/braincom/edeno/conda_envs/Categorize_Replay_2017/lib/python3.6/site-packages/seaborn/categorical.py in plot(self, ax)
#    1778     def plot(self, ax):
#    1779         """Make the plot."""
# -> 1780         self.draw_points(ax)
#    1781         self.annotate_axes(ax)
#    1782         if self.orient == "h":
#
# /projectnb/braincom/edeno/conda_envs/Categorize_Replay_2017/lib/python3.6/site-packages/seaborn/categorical.py in draw_points(self, ax)
#    1774                                c=[self.colors[j]] * len(offpos),
#    1775                                linewidth=mew, marker=marker, s=markersize,
# -> 1776                                edgecolor=self.colors[j], zorder=z)
#    1777
#    1778     def plot(self, ax):
#
# /projectnb/braincom/edeno/conda_envs/Categorize_Replay_2017/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1896                     warnings.warn(msg % (label_namer, func.__name__),
#    1897                                   RuntimeWarning, stacklevel=2)
# -> 1898             return func(ax, *args, **kwargs)
#    1899         pre_doc = inner.__doc__
#    1900         if pre_doc is None:
#
# /projectnb/braincom/edeno/conda_envs/Categorize_Replay_2017/lib/python3.6/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, **kwargs)
#    4032                 offsets=offsets,
#    4033                 transOffset=kwargs.pop('transform', self.transData),
# -> 4034                 alpha=alpha
#    4035                 )
#    4036         collection.set_transform(mtransforms.IdentityTransform())
#
# /projectnb/braincom/edeno/conda_envs/Categorize_Replay_2017/lib/python3.6/site-packages/matplotlib/collections.py in __init__(self, paths, sizes, **kwargs)
#     900         """
#     901
# --> 902         Collection.__init__(self, **kwargs)
#     903         self.set_paths(paths)
#     904         self.set_sizes(sizes)
#
# /projectnb/braincom/edeno/conda_envs/Categorize_Replay_2017/lib/python3.6/site-packages/matplotlib/collections.py in __init__(self, edgecolors, facecolors, linewidths, linestyles, antialiaseds, offsets, transOffset, norm, cmap, pickradius, hatch, urls, offset_position, zorder, **kwargs)
#     139         self._hatch_color = mcolors.to_rgba(mpl.rcParams['hatch.color'])
#     140         self.set_facecolor(facecolors)
# --> 141         self.set_edgecolor(edgecolors)
#     142         self.set_linewidth(linewidths)
#     143         self.set_linestyle(linestyles)
#
# /projectnb/braincom/edeno/conda_envs/Categorize_Replay_2017/lib/python3.6/site-packages/matplotlib/collections.py in set_edgecolor(self, c)
#     739         """
#     740         self._original_edgecolor = c
# --> 741         self._set_edgecolor(c)
#     742
#     743     def set_edgecolors(self, c):
#
# /projectnb/braincom/edeno/conda_envs/Categorize_Replay_2017/lib/python3.6/site-packages/matplotlib/collections.py in _set_edgecolor(self, c)
#     720         except AttributeError:
#     721             pass
# --> 722         self._edgecolors = mcolors.to_rgba_array(c, self._alpha)
#     723         if set_hatch_color and len(self._edgecolors):
#     724             self._hatch_color = tuple(self._edgecolors[0])
#
# /projectnb/braincom/edeno/conda_envs/Categorize_Replay_2017/lib/python3.6/site-packages/matplotlib/colors.py in to_rgba_array(c, alpha)
#     237     result = np.empty((len(c), 4), float)
#     238     for i, cc in enumerate(c):
# --> 239         result[i] = to_rgba(cc, alpha)
#     240     return result
#     241
#
# /projectnb/braincom/edeno/conda_envs/Categorize_Replay_2017/lib/python3.6/site-packages/matplotlib/colors.py in to_rgba(c, alpha)
#     141         rgba = _colors_full_map.cache[c, alpha]
#     142     except (KeyError, TypeError):  # Not in cache, or unhashable.
# --> 143         rgba = _to_rgba_no_colorcycle(c, alpha)
#     144         try:
#     145             _colors_full_map.cache[c, alpha] = rgba
#
# /projectnb/braincom/edeno/conda_envs/Categorize_Replay_2017/lib/python3.6/site-packages/matplotlib/colors.py in _to_rgba_no_colorcycle(c, alpha)
#     192         # float)` and `np.array(...).astype(float)` all convert "0.5" to 0.5.
#     193         # Test dimensionality to reject single floats.
# --> 194         raise ValueError("Invalid RGBA argument: {!r}".format(orig_c))
#     195     # Return a tuple to prevent the cached value from being modified.
#     196     c = tuple(c.astype(float))
#
# ValueError: Invalid RGBA argument: 0.33999999999999997

# %%
covariate = 'replay_order'
percentage_of_ripples = (replay_info
 .groupby(['animal', 'day', 'epoch', 'session_time'])[covariate].value_counts(normalize=True)
 .rename('percentage of ripples').reset_index())

sns.factorplot(data=percentage_of_ripples, x='session_time', y='percentage of ripples', hue=covariate, palette=COLORS);
sns.factorplot(data=percentage_of_ripples, x='session_time', y='percentage of ripples', hue=covariate,
               col='animal', palette=COLORS, col_wrap=3);
sns.factorplot(data=percentage_of_ripples, x='session_time', y='percentage of ripples', hue=covariate,
               kind='swarm', palette=COLORS);
sns.factorplot(data=percentage_of_ripples, x='session_time', y='percentage of ripples', hue=covariate,
               col='animal', col_wrap=3, kind='swarm', palette=COLORS);

# %%
covariate = 'replay_task'
percentage_of_ripples = (replay_info
 .groupby(['animal', 'day', 'epoch', 'session_time'])[covariate].value_counts(normalize=True)
 .rename('percentage of ripples').reset_index())

sns.factorplot(data=percentage_of_ripples, x='session_time', y='percentage of ripples', hue=covariate, palette=COLORS);
sns.factorplot(data=percentage_of_ripples, x='session_time', y='percentage of ripples', hue=covariate,
               col='animal', palette=COLORS, col_wrap=3);
sns.factorplot(data=percentage_of_ripples, x='session_time', y='percentage of ripples', hue=covariate,
               kind='swarm', palette=COLORS);
sns.factorplot(data=percentage_of_ripples, x='session_time', y='percentage of ripples', hue=covariate,
               col='animal', col_wrap=3, kind='swarm', palette=COLORS);

# %%
covariate = 'predicted_state'
replay_percentage = (replay_info
 .groupby(['animal', 'day', 'epoch', 'session_time'])[covariate].value_counts(normalize=True)
 .rename('% ripples').reset_index())

sns.factorplot(data=replay_percentage, x='session_time', y='% ripples', hue=covariate, palette=COLORS);
sns.factorplot(data=replay_percentage, x='session_time', y='% ripples',
               hue=covariate, col='animal', col_wrap=3, palette=COLORS);
sns.factorplot(data=replay_percentage, x='session_time', y='% ripples',
               hue=covariate, kind='swarm', palette=COLORS);
sns.factorplot(data=replay_percentage, x='session_time', y='% ripples', hue=covariate,
               col='animal', col_wrap=3, kind='swarm', palette=COLORS);

# %% [markdown]
# ## Position of Animal during Replay Types

# %%
position_occupancy = (
    xr.open_mfdataset(PROCESSED_DATA_DIR + '/*.nc', group='position_occupancy')
    .to_dataframe()
    .set_index(['animal', 'day', 'epoch']))
position_occupancy = position_occupancy.join(epoch_info.environment.astype(str))

# %%
po = position_occupancy.groupby(['animal', 'environment', 'center_x', 'center_y']).sum()

# %%
replay_info = (replay_info
               .reset_index('ripple_number')
               .join(epoch_info.environment.astype(str))
               .set_index('ripple_number', append=True))

# %%
from src.parameters import GRIDSIZE, EXTENT, SAMPLING_FREQUENCY

covariate = 'replay_task'
for name, group in replay_info.groupby(['animal', 'environment']):
    grouped = group.groupby(covariate)
    n_levels = len(grouped)
    fig, axes = plt.subplots(1, n_levels, figsize=(5 * n_levels, 5), sharex=True, sharey=True)
    occ = po.xs(name[:2]).reset_index()
    for ax, (level, level_group) in zip(axes, grouped):
        event_count = ax.hexbin(level_group.x_position, level_group.y_position,
                                gridsize=GRIDSIZE, extent=EXTENT).get_array()
        ax.cla()
        normalized_count = SAMPLING_FREQUENCY * event_count / occ.occupancy_count.values
        mappable = ax.hexbin(occ.center_x, occ.center_y,
                             C=normalized_count, gridsize=GRIDSIZE, extent=EXTENT,
                             cmap=sns.light_palette(COLORS[level], as_cmap=True), vmin=0, vmax=0.5)
        ax.set_title(level)
        xlim = np.percentile(occ.center_x[~np.isinf(normalized_count) & ~np.isnan(normalized_count)], [0, 100])
        ylim = np.percentile(occ.center_y[~np.isinf(normalized_count) & ~np.isnan(normalized_count)], [0, 100])
        ax.set_xlim(xlim + [-5, 5])
        ax.set_ylim(ylim + [-5, 5])
    fig.suptitle(name)
    plt.tight_layout()

# %%
from src.parameters import GRIDSIZE, EXTENT, SAMPLING_FREQUENCY

covariate = 'replay_order'
for name, group in replay_info.groupby(['animal', 'environment']):
    grouped = group.groupby(covariate)
    n_levels = len(grouped)
    fig, axes = plt.subplots(1, n_levels, figsize=(5 * n_levels, 5), sharex=True, sharey=True)
    occ = po.xs(name[:2]).reset_index()
    for ax, (level, level_group) in zip(axes, grouped):
        event_count = ax.hexbin(level_group.x_position, level_group.y_position,
                                gridsize=GRIDSIZE, extent=EXTENT).get_array()
        ax.cla()
        normalized_count = SAMPLING_FREQUENCY * event_count / occ.occupancy_count.values
        mappable = ax.hexbin(occ.center_x, occ.center_y,
                             C=normalized_count, gridsize=GRIDSIZE, extent=EXTENT,
                             cmap=sns.light_palette(COLORS[level], as_cmap=True), vmin=0, vmax=0.5)
        ax.set_title(level)
        xlim = np.percentile(occ.center_x[~np.isinf(normalized_count) & ~np.isnan(normalized_count)], [0, 100])
        ylim = np.percentile(occ.center_y[~np.isinf(normalized_count) & ~np.isnan(normalized_count)], [0, 100])
        ax.set_xlim(xlim + [-5, 5])
        ax.set_ylim(ylim + [-5, 5])
    fig.suptitle(name)
    plt.tight_layout()

# %%
from src.parameters import GRIDSIZE, EXTENT, SAMPLING_FREQUENCY

covariate = 'replay_motion'
for name, group in replay_info.groupby(['animal', 'environment']):
    grouped = group.groupby(covariate)
    n_levels = len(grouped)
    fig, axes = plt.subplots(1, n_levels, figsize=(5 * n_levels, 5), sharex=True, sharey=True)
    occ = po.xs(name[:2]).reset_index()
    for ax, (level, level_group) in zip(axes, grouped):
        event_count = ax.hexbin(level_group.x_position, level_group.y_position,
                                gridsize=GRIDSIZE, extent=EXTENT).get_array()
        ax.cla()
        normalized_count = SAMPLING_FREQUENCY * event_count / occ.occupancy_count.values
        mappable = ax.hexbin(occ.center_x, occ.center_y,
                             C=normalized_count, gridsize=GRIDSIZE, extent=EXTENT,
                             cmap=sns.light_palette(COLORS[level], as_cmap=True), vmin=0, vmax=0.5)
        ax.set_title(level)
        xlim = np.percentile(occ.center_x[~np.isinf(normalized_count) & ~np.isnan(normalized_count)], [0, 100])
        ylim = np.percentile(occ.center_y[~np.isinf(normalized_count) & ~np.isnan(normalized_count)], [0, 100])
        ax.set_xlim(xlim + [-5, 5])
        ax.set_ylim(ylim + [-5, 5])
    fig.suptitle(name)
    plt.tight_layout()

# %%
from src.parameters import GRIDSIZE, EXTENT, SAMPLING_FREQUENCY

covariate = 'session_time'
for name, group in replay_info.groupby(['animal', 'environment']):
    grouped = group.groupby(covariate)
    n_levels = len(grouped)
    fig, axes = plt.subplots(1, n_levels, figsize=(5 * n_levels, 5), sharex=True, sharey=True)
    occ = po.xs(name[:2]).reset_index()
    for ax, (level, level_group) in zip(axes, grouped):
        event_count = ax.hexbin(level_group.x_position, level_group.y_position,
                                gridsize=GRIDSIZE, extent=EXTENT).get_array()
        ax.cla()
        normalized_count = SAMPLING_FREQUENCY * event_count / occ.occupancy_count.values
        mappable = ax.hexbin(occ.center_x, occ.center_y,
                             C=normalized_count, gridsize=GRIDSIZE, extent=EXTENT,
                             cmap='viridis', vmin=0, vmax=1)
        ax.set_title(level)
        xlim = np.percentile(occ.center_x[~np.isinf(normalized_count) & ~np.isnan(normalized_count)], [0, 100])
        ylim = np.percentile(occ.center_y[~np.isinf(normalized_count) & ~np.isnan(normalized_count)], [0, 100])
        ax.set_xlim(xlim + [-5, 5])
        ax.set_ylim(ylim + [-5, 5])
    fig.suptitle(name)
    plt.tight_layout()

# %%
from src.parameters import GRIDSIZE, EXTENT, SAMPLING_FREQUENCY

covariate = 'predicted_state'
for name, group in replay_info.groupby(['animal', 'environment']):
    grouped = group.groupby(covariate)
    n_levels = len(grouped)
    fig, axes = plt.subplots(1, n_levels, figsize=(5 * n_levels, 5), sharex=True, sharey=True)
    occ = po.xs(name[:2]).reset_index()
    for ax, (level, level_group) in zip(axes, grouped):
        event_count = ax.hexbin(level_group.x_position, level_group.y_position,
                                gridsize=GRIDSIZE, extent=EXTENT).get_array()
        ax.cla()
        normalized_count = SAMPLING_FREQUENCY * event_count / occ.occupancy_count.values
        mappable = ax.hexbin(occ.center_x, occ.center_y,
                             C=normalized_count, gridsize=GRIDSIZE, extent=EXTENT,
                             cmap=sns.light_palette(COLORS[level], as_cmap=True), vmin=0, vmax=0.5)
        ax.set_title(level)
        xlim = np.percentile(occ.center_x[~np.isinf(normalized_count) & ~np.isnan(normalized_count)], [0, 100])
        ylim = np.percentile(occ.center_y[~np.isinf(normalized_count) & ~np.isnan(normalized_count)], [0, 100])
        ax.set_xlim(xlim + [-5, 5])
        ax.set_ylim(ylim + [-5, 5])
    fig.suptitle(name)
    plt.tight_layout()
